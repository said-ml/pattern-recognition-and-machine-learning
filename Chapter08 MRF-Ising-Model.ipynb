# %% [markdown]
# # Markov_Random_Field:

# %% [markdown]
# firstly before implement the ising-alogorithm we should give a sight description of this algorithm(Mathematic's view of algorithm):
#
#
# consider $(i, j)$ a pair in a set $\mathbb{N}^2$, it obvious that neghbors surround $(i, j)$ are $\{(i-1, j), (i+1, j), (i, j-1),(i, j+1)\}$ with some exceptionality in the cases i,j $\in \{0,N\}$
#
# The algorithm of ising model is given by:

# %%
import numpy as np
from numpy.random import random
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from numba import jit # to make code more faster
from typing import Tuple, List, List, Optional
from numpy.random import random
from  skimage.io import imread
import tqdm as tq

image = imread("/home/said/Pictures/Screenshots/Screenshot from 2022-10-07 08-13-09.png")
fig, axes = plt.subplots(figsize=(10,6))
axes.imshow(image,cmap=cm.gray, aspect="equal", interpolation="none", vmin=-1, vmax=1)

# %%
def ising_algorithm(X, beta=0.1, niter=1000):
    Z=X.copy()
    for k in range(niter):
        for k

# %% [markdown]
# # The Ising Model:

# %%
image = skimage.io.imread("/home/said/Downloads/img.jpeg")
fig, axes = plt.subplots(figsize=(10,6))
axes.imshow(image,cmap=cm.gray, aspect="equal", interpolation="none", vmin=-1, vmax=1)

# %%
class Ising_Model
 
   Matrix=List[List]
   @jit
   def __init__(self,X:np.array(()), Y:np.array(())->None:
    self.X=X
    self.Y=Y 
    assert X.shape==Y.shape
                
   @jit
   def origin_image(self, image)->Optional[Matrix]:
      self.image=image
      image = skimage.io.imread(image)
      fig, axes = plt.subplots(figsize=(10,6))
      axes.imshow(image, cmap=cm.gray, aspect="equal", interpolation="none", vmin=-1, vmax=1)

   def neighbors(i:int,j:int)->List[Tuple]:
      return [(k,l) for k,l in zip([i-1, i, i+1, i], [j,j-1, j, j+1])]

   @jit
   def num_rows_cols(X:List[List])->Tuple[int, int]:
     return X.shape

   @jit
   def local_energy(self, X:np.array(()), int:i, int:j)->float:
        E_l=[]
        for k,j in self.neighbors(i, j):
                E_l.append(X[k,j])
        return E_l.sum()
                
   @jit
   def total_energy(self,X:np.array(()) )->float:
            E=0
            for i,j in zip(self.num_rows_cols):
                E+=self.local_energy(X,i,j)
            return E
                
   @jit
   def X_0_1(N:int, M:int)->List[List]:
      return [[int(random()) for k in range(M)]for l in range(N)]
    
   @jit
   def denosing_image(self, X:np.array(()))
        X=X.copy()
        s=0
        with tq.trange(3,n) as t:
            for k in t:
                for i, j in zip(self.num_rows_col):
                  s=X[i]

# %%
set={''}
set.add(0 if random()>0.5 else 1 for  i in  range(100))
set
# Out:
# {'', 0, 1}
