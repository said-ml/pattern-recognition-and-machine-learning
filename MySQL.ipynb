# %% [markdown]
# # What is SQL? :

# %% [markdown]
# $SQL$ is a $Structered $ $~$ $Query$ $~$ $Language$ that aiming to operate and retrieve data from databeses through performing $query $$~$$statements$, it is written in $C/C++$.
#
# $SQL$ is pretty crucial in domaine that overllape with $Data$.

# %% [markdown]
# # What is MySQL?:

# %% [markdown]
# $MySQL$ is a free open source tool for database admistration, in other word  is $RDBMS$ that stands for $Relational$$~$$ DataBase $$~$$Management $$~$$System$, there is a lots of the $RDBMSs$ in the market (e,g $Postgree$, $SQL server$...etc), there a slight differences between them in the  $Syntax$ level, so it sufficient to pick one and master it, in our case we pick $MySQL$.

# %% [markdown]
# # Wht is $Clause$?:

# %% [markdown]
# if the procedural languages(e,g $python$, $java$, ...)rely on loqique tools as loops(e,g $ for $, $while$, $if$, $else$,...),function(e,g $def$ myfunction: in $python$...), class...etc, $SQL$ rely on $clause$ that is predefinie function that give us the ability to manipulate and filter data, the collection of the $clause$ called a $query$.
# we perform $queries$ through the  $clauses$ such as  $select$, $update$, $insert$, $delect$,...etc

# %% [markdown]
# # Which IDE for practice?

# %% [markdown]
# before  move a head make sure to install $MySQL$ in your system ($MySQL$$~$$workbench$ as Interface Graphics), or at least execute the code through the online IDE.'if you don't use it you lose it'.
# we deal with a tables(collection of structured dows and columns) as it showen by the following image.

# %% [markdown]
# ![Captureaa.PNG](attachment:Captureaa.PNG)

# %% [markdown]
# if you're getting stuck in some issue's installation, you can check out these online ide https://onecompiler.com/mysql

# %% [markdown]
# # How to show your data ?

# %% [markdown]
# in our cases data are tables or a set of tables , so we show data through the followng :

# %% [markdown]
# ![Captureac.PNG](attachment:Captureac.PNG)

# %% [markdown]
# each database is a set a set of tables, try it :

# %% [markdown]
# ![Capturead.PNG](attachment:Capturead.PNG)

# %% [markdown]
# unlike other programming languges, uppercase or lowercase don't play any role when we performs queries on the databases, so we can writte also:

# %% [markdown]
# we know now that our data are $actor$, $adress$, $city$,...etc

# %% [markdown]
# # How to explore the content of a table?

# %% [markdown]
# we explore our table though the following syntax:

# %% [markdown]
# ![ae.PNG](attachment:ae.PNG)

# %% [markdown]
# to make our code more clear, we're commented using /* these is just commentaire */

# %% [markdown]
# # How to filter data in a a table?

# %% [markdown]
# in general, we performs filtering through conditions over $columns$(i.e $features$ in context of the data science) or $rows$ (i.e $samples$ in the context of data science)or even both:

# %% [markdown]
# ![s.PNG](attachment:s.PNG)

# %% [markdown]
# we can introduce $alias$ as a mechanism that allows us temporarely to rename our $columns$ and make them more readeable, the $as$ are optional even it makes the $code$ more clear:

# %% [markdown]
# ![Capturel.PNG](attachment:Capturel.PNG)

# %% [markdown]
# as i said before, the $~$$as$ key optional, the result of the previous code doesn't change if does'nt include $as$.

# %% [markdown]
# # How to create a table ?

# %% [markdown]
# yes as you guess, through the $create $$~~$$table$$~~$name_table statement, suppose for example we want to create student's table that contenants the first and lastname of the student , his(her) age, his(her) result in the examen, his(her) gender.
# so we have $4$ columns:
#
# ==>firstName, lastName are both list of characters, we choose them  as a variable charachter with maximal length is $40$
#
# ==>age is $int$
#
# ==>result: $float$ between 0 and 20.
#
# ==> gender is a $bool$, 'M' for 'Male' and 'F'for 'Female'.
#
# we regroup all these informations together we're getting the following pseudocode:

# %% [markdown]
# $create$$~$$ table$ student
#
#        (firtName    VarChar(10) not null,
#         lastName    VarChar(10) not null,
#         result      float not null,
#         age         smallint not null,
#         gender      varchar(1) not null
#
#         );
#
#  but before move on, and write down these in IDE, it seem that we're facing at least two issues:
#
#  $a$==>during the fill of table it might be filled with a duplicated rows.
#
#  $b$==>as you previousely know with a relational database, so it might be need to $join$ these tble with another tables.
#
#  there another issues ,we fix those issues through the $constraints$ $~$$key$.
#
#  $Primary$$~$$key$ is the solution the first due it guarantee that the rows are unique.
#
#  $Foreign$$~$$key$ is the solution of the second issue, that allows us to $join$ at least two tables .
#
#  to simplify things, we create the $student$ without $foreign$ $~$$key$, we will added later when we create other table.

# %% [markdown]
# ![Captureg.PNG](attachment:Captureg.PNG)

# %% [markdown]
# as you see, we add $if$$~$$not$$~$$exists$ due when we rerun the code we're getting the error,'Table student already exists'

# %% [markdown]
# # how to insert data in the table?

# %% [markdown]
# we insert data in table through the following syntax:
#
# $insert$$~$$into$$~$$table$(column_0, column_1,...,column_N)
#
# $values$(value00, value01,...,value0N),
#
#       (value10, value11,...,value1N),
#
#       ......
#
#       (valueM0, valueM1,...,valueMN);

# %% [markdown]
# ![Capturej.PNG](attachment:Capturej.PNG)

# %% [markdown]
#  # How to realate two tables in a relational databases?

# %% [markdown]
# first of all, let's create the  $teacher$ table, the purpose of the following paragraph is to realte ($join$) the $student$ table with the $teacher$ table, the following $code$ crete and fill up the $teacher$ table.

# %% [markdown]
# ![Capturen.PNG](attachment:Capturen.PNG)

# %% [markdown]
# ![Capturemn.PNG](attachment:Capturemn.PNG)

# %% [markdown]
# as you can observe, the column that link the $teacher$ and the $student$ table is city_id, so to create a relation between the the two table we must add the $constraint$ $~$$Foreign$$~$$Key$ to the $student$ table as the following $code$ demonstrate:

# %% [markdown]
# ![nm.PNG](attachment:nm.PNG)

# %% [markdown]
# the key word $desc$ is for describing the table.

# %% [markdown]
# remember, don't rerun the command more than one time, that might generated an error ,for example if you rerun the code of the lines 3 and 4 you generate an error of duplicate foreign key, you can drop it through the command:
#
# $alter$$~$ $table$$~$ $student$$~$ $drop$ $~$$foreign$ $~$$key$ $~$$fk$;
#
# avoid these issue by deleting the commad when it run successfully or selecting the target command.

# %% [markdown]
# # What are joins in MySQL?

# %% [markdown]
# In the $MySQL$'s context, the $joins$ is the mechanism that enable us to retrieve, manipulate , operate from a sevral tables and get it as one single result, actually that's is possible if the tables are connected(i,e, $foreign$$~$$key$.
#
# In these section,w'll go through the all genres of the $joins$.
#
# Before move a head, we need several connected tables to play with it, we will work with tables of $sakila$'s shema.

# %% [markdown]
# ![CaptureEER.PNG](attachment:CaptureEER.PNG)

# %% [markdown]
# # What's Column Alias?

# %% [markdown]
# $alias$ $~$ is a mechanism that give a table or column a temporary name, we perform that through the command:

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# the key word $as$ is optional, we're getting the result:

# %% [markdown]
# ![Capture0.PNG](attachment:Capture0.PNG)

# %% [markdown]
# # Rows Filtering?

# %% [markdown]
# often we don't interested in the whole data, instead we intersted in partial data with a perticular properties, the most $clauses$ that performs conditions in data are $where$, $group$$~$$by$ , $having$, $limit$,...,and each $clause$ has their own
# $subclauses$(e,g $where$ has $or$, $and$,$=$,$>$ ...etc).
#
# suppose for example we want to know the students that failed in the examen, that's mean the condions are $result<10$, that's justify the following query:

# %% [markdown]
# ![Capture4.PNG](attachment:Capture4.PNG)

# %% [markdown]
# we're getting the result:

# %% [markdown]
# ![Capture5.PNG](attachment:Capture5.PNG)

# %% [markdown]
# if all the rows in the table does not fit our conditions, we're getting a empty set as the following code show:

# %% [markdown]
# ![Capture6.PNG](attachment:Capture6.PNG)

# %% [markdown]
# the result is:

# %% [markdown]
# ![Capture7.PNG](attachment:Capture7.PNG)

# %% [markdown]
# We can make rows in order through the $order$ $~$ $by$ clause:

# %% [markdown]
# ![Capture9.PNG](attachment:Capture9.PNG)

# %%
we obtain that:

# %% [markdown]
# ![Capture11.PNG](attachment:Capture11.PNG)

# %% [markdown]
# if we want to reverse the order, we add the $desc$ key ,and also instead of written down the name of column we can just mentioned the number of column , above the $result$ are the third column:

# %% [markdown]
# ![Capture13.PNG](attachment:Capture13.PNG)

# %% [markdown]
# in these following sections we intending to deal with set of tables that avaible in our database, check out it by performing the command:

# %% [markdown]
# ![14.PNG](attachment:14.PNG)

# %% [markdown]
# the image below give us a thorough informations about the content and constructions of the tables:

# %% [markdown]
# ![15.PNG](attachment:15.PNG)

# %% [markdown]
# as you see every table is at least linked with another table, this limks we serve us well to perform a lot of operations, but before dive deep in data manipulation we need to define some fundamental $key$ words (e,g $Foreign$$~$$Key$).

# %% [markdown]
# # What is Primary Key, Foreign  Key?

# %% [markdown]
# suppose we have add that row into the $student$ table:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# two persons with the same features does not means the two persons are identicals (e,g the row 1 and 5), to fix these issue we add feature that called $Primary$ $Key$ to guarantee that the rows are unique, we $alter$ the $student$ table as the following:
